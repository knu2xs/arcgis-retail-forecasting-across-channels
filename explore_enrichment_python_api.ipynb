# %%
from arcgis.gis import GIS
import arcgis.geoenrichment as geoenrichment

# %%
user_id = 'jmccune_geoai'
customer_item_id = '47d2cb05d9c1494797293b62ba167211'

# %%
gis = GIS(username=user_id)
gis
# Out:
# Enter password: ········
# GIS @ <a href="https://geoai.maps.arcgis.com">https://geoai.maps.arcgis.com</a>

# %%
usa = geoenrichment.Country.get('US')
usa
# Out:
# <Country name:United States>

# %%
factors_df = usa.data_collections
print('There are {:,} data variables available from Esri.'.format(len(factors_df.index)))
# Out:
# There are 14,630 data variables available from Esri.

# %%
disposableincome_factors_df = factors_df[factors_df.index == 'disposableincome'].copy()
print('For just disposable income there are {:,} variables!'.format(len(disposableincome_factors_df.index)))
# Out:
# For just disposable income there are 104 variables!

# %%
mediandi_factors_df = disposableincome_factors_df[disposableincome_factors_df['alias'].str.contains('Median')]
mediandi_factors_df
# Out:
#                              analysisVariable  \
# dataCollectionID
# disposableincome    disposableincome.MEDDI_CY
# disposableincome  disposableincome.MEDDIA15CY
# disposableincome  disposableincome.MEDDIA25CY
# disposableincome  disposableincome.MEDDIA35CY
# disposableincome  disposableincome.MEDDIA45CY
# disposableincome  disposableincome.MEDDIA55CY
# disposableincome  disposableincome.MEDDIA65CY
# disposableincome  disposableincome.MEDDIA75CY
#
#                                                   alias  \
# dataCollectionID
# disposableincome          2018 Median Disposable Income
# disposableincome  2018 Median Disposable Inc: HHr 15-24
# disposableincome  2018 Median Disposable Inc: HHr 25-34
# disposableincome  2018 Median Disposable Inc: HHr 35-44
# disposableincome  2018 Median Disposable Inc: HHr 45-54
# disposableincome  2018 Median Disposable Inc: HHr 55-64
# disposableincome  2018 Median Disposable Inc: HHr 65-74
# disposableincome    2018 Median Disposable Inc: HHr 75+
#
#                                          fieldCategory vintage
# dataCollectionID
# disposableincome         2018 Disposable Income (Esri)    2018
# disposableincome  2018 Disposable Income by Age (Esri)    2018
# disposableincome  2018 Disposable Income by Age (Esri)    2018
# disposableincome  2018 Disposable Income by Age (Esri)    2018
# disposableincome  2018 Disposable Income by Age (Esri)    2018
# disposableincome  2018 Disposable Income by Age (Esri)    2018
# disposableincome  2018 Disposable Income by Age (Esri)    2018
# disposableincome  2018 Disposable Income by Age (Esri)    2018

# %%
enrich_variable_list = list(mediandi_factors_df['analysisVariable'].values)
enrich_variable_list
# Out:
# ['disposableincome.MEDDI_CY',
#  'disposableincome.MEDDIA15CY',
#  'disposableincome.MEDDIA25CY',
#  'disposableincome.MEDDIA35CY',
#  'disposableincome.MEDDIA45CY',
#  'disposableincome.MEDDIA55CY',
#  'disposableincome.MEDDIA65CY',
#  'disposableincome.MEDDIA75CY']

# %%
from arcgis.gis import Item

customer_layer = Item(gis, customer_item_id).layers[0]
customer_layer
# Out:
# <FeatureLayer url:"https://services.arcgis.com/PMTtzuTB6WiPuNSv/arcgis/rest/services/Customers_Update/FeatureServer/0">

# %%
id_list = customer_layer.query(return_ids_only=True)
enrich_id_list = [str(id) for id in id_list['objectIds'][:3]]
enrich_id_string = ','.join(enrich_id_list)
enrich_id_string
# Out:
# '1,2,3'

# %%
customer_sdf = customer_layer.query(object_ids=enrich_id_string).df
customer_sdf
# Out:
#          CITY CUSTOMER_CLASS  Customer_Spending                    DMA  \
# 0  Prattville         Steady             3527.8  Montgomery (Selma) AL
# 1  Prattville         Steady             2667.1  Montgomery (Selma) AL
# 2  Prattville         Steady             2897.6  Montgomery (Selma) AL
#
#        Distance FIRSTNAME  Join_Count LASTNAME  OBJECTID PAYMETHOD  \
# 0  57691.556784       JIM           2    BROWN         1        MC
# 1  57691.556784      CARL           2   ATKINS         2        MC
# 2  57691.556784      JOHN           2    ASHBY         3        PP
#
#                          ...                         Store_ID  TARGET_FID  \
# 0                        ...                             None           1
# 1                        ...                             None           2
# 2                        ...                             None           3
#
#       X_Long      Y_Lat    ZIP  ZIP4  \
# 0 -86.497305  32.474348  36067  2816
# 1 -86.478971  32.481213  36067  1814
# 2 -86.457961  32.485113  36067  2110
#
#                                          description  test time_of_day  \
# 0  Island hemp skirt - The Island Hemp Skirt brin...  None        None
# 1  Vintage logo pkt t-shirt - Keep it on the down...  None        None
# 2  Solimar pants - In case your travel plans coin...  None        None
#
#                                                SHAPE
# 0  {'x': -9628835.9624, 'y': 3825738.4985999987, ...
# 1  {'x': -9626795.0102, 'y': 3826644.4267000034, ...
# 2  {'x': -9624456.2475, 'y': 3827159.0424999967, ...
#
# [3 rows x 24 columns]

# %%
enrich_df = geoenrichment.enrich(
    study_areas=customer_sdf[['SHAPE']].copy(), # only send the geometry
    analysis_variables=enrich_variable_list,
    return_geometry=False  # already have the geometry locally, so do not repeat
)
enrich_df.set_index('ID', drop=True, inplace=True)  # index to match with original data
enrich_df.index = enrich_df.index.astype(customer_sdf.index.dtype)  # so the join will work later
enrich_df.drop([col for col in enrich_df.columns if 'OBJECTID' in col], inplace=True, axis=1)
enrich_df
# Out:
#     HasData  MEDDIA15CY  MEDDIA25CY  MEDDIA35CY  MEDDIA45CY  MEDDIA55CY  \
# ID
# 0         1       30717       51239       61686       70704       52912
# 1         1       30717       50397       54461       57858       45039
# 2         1       36263       47177       54538       57423       48567
#
#     MEDDIA65CY  MEDDIA75CY  MEDDI_CY                  aggregationMethod  \
# ID
# 0        42742       27632     51445  BlockApportionment:US.BlockGroups
# 1        39248       27789     46602  BlockApportionment:US.BlockGroups
# 2        46279       34101     48455  BlockApportionment:US.BlockGroups
#
#       areaType  bufferRadii bufferUnits bufferUnitsAlias sourceCountry
# ID
# 0   RingBuffer            1   esriMiles            Miles            US
# 1   RingBuffer            1   esriMiles            Miles            US
# 2   RingBuffer            1   esriMiles            Miles            US

# %%
customer_enrich_sdf = customer_sdf.join(enrich_df)
customer_enrich_sdf
# Out:
#          CITY CUSTOMER_CLASS  Customer_Spending                    DMA  \
# 0  Prattville         Steady             3527.8  Montgomery (Selma) AL
# 1  Prattville         Steady             2667.1  Montgomery (Selma) AL
# 2  Prattville         Steady             2897.6  Montgomery (Selma) AL
#
#        Distance FIRSTNAME  Join_Count LASTNAME  OBJECTID PAYMETHOD  \
# 0  57691.556784       JIM           2    BROWN         1        MC
# 1  57691.556784      CARL           2   ATKINS         2        MC
# 2  57691.556784      JOHN           2    ASHBY         3        PP
#
#        ...      MEDDIA55CY  MEDDIA65CY MEDDIA75CY MEDDI_CY  \
# 0      ...           52912       42742      27632    51445
# 1      ...           45039       39248      27789    46602
# 2      ...           48567       46279      34101    48455
#
#                    aggregationMethod    areaType  bufferRadii  bufferUnits  \
# 0  BlockApportionment:US.BlockGroups  RingBuffer            1    esriMiles
# 1  BlockApportionment:US.BlockGroups  RingBuffer            1    esriMiles
# 2  BlockApportionment:US.BlockGroups  RingBuffer            1    esriMiles
#
#   bufferUnitsAlias sourceCountry
# 0            Miles            US
# 1            Miles            US
# 2            Miles            US
#
# [3 rows x 39 columns]
